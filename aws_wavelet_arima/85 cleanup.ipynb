# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

# %%
pred = np.load('pred.npy')

# %%
data = pd.read_csv('aapl_indicators_yahoo.csv')['Close']

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
pred = scaler.fit_transform(np.array(pred).reshape(-1,1))
data = scaler.transform(np.array(data).reshape(-1,1))

# %%
test_n = len(data)*4//5

# %%
actual = np.array(data)[test_n:]

# %%
plt.plot(pred, color='r')
plt.plot(actual, color='g')

# %%
pred1 = pred[:990]
actual1 = actual[:990]

# %%
plt.plot(pred1, color='r')
plt.plot(actual1, color='g')
plt.savefig('84actual.png')

# %%
actual1 = np.array(actual1[:,0])
pred1 = np.array(pred1[:,0])

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    return(mape)

# %%
mse = mean_squared_error(actual1, pred1)
rmse = math.sqrt(mse)
mae = mean_absolute_error(actual1, pred1)
mape = mean_absolute_percentage_error(actual1, pred1)

# %%
print(mse, rmse, mae, mape)
# Out:
# 0.0003856979713785479 0.019639194774189392 0.013374267114217069 68.6905766971053
