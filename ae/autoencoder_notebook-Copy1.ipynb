# %%
from models.autoencoder import AutoEncoder
from models.nnmodel import NNModel
from models.rfmodel import RFModel
from data_processor.data_processing import DataProcessing
import pandas as pd
import numpy as np 
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from data_processor.base_bars import BaseBars
# Out:
# Using TensorFlow backend.

# %%
import time

# %%
start = time.time()

# %%
features = pd.read_csv('/Users/andyliu/develop/andy/aapl_indicators_nosplit.csv')

# %%
features.head()
# Out:
#    Unnamed: 0     date    open   close     low    high  volume    bb_bbm  \
# 0          25   2/8/00  4.0714  4.1027  3.9755  4.1451       0  3.742555
# 1          26   2/9/00  4.0804  4.0224  4.0179  4.1786       0  3.778050
# 2          27  2/10/00  4.0224  4.0536  3.9130  4.0670       0  3.825040
# 3          28  2/11/00  4.0581  3.8840  3.8706  4.0759       0  3.846470
# 4          29  2/14/00  3.9018  4.1362  3.8840  4.1384       0  3.873925
#
#      bb_bbh    bb_bbl       atr      macd         cci       ema       roc  \
# 0  4.258224  3.226886  0.258809  0.028209  108.782044  3.824942  3.199598
# 1  4.267487  3.288613  0.251801  0.041007   99.551288  3.851270  6.000474
# 2  4.222099  3.427981  0.244815  0.053055   72.677158  3.878247  1.115019
# 3  4.205897  3.487043  0.241993  0.048361   40.605138  3.879014 -1.303585
# 4  4.233795  3.514055  0.242879  0.064250   80.649750  3.913306  5.284325
#
#       sma12     sma5  stochastic_oscillator       mtm6     mtm12
# 0  3.819608  3.85050              75.940406  10.722189  3.199598
# 1  3.838583  3.94916              80.342311  12.344989  6.000474
# 2  3.842308  4.02192              84.268815  14.862146  1.115019
# 3  3.838033  4.02728              62.924742   5.263158 -1.303585
# 4  3.855333  4.03978              94.663982   7.233226  5.284325

# %%
features = features.drop('Unnamed: 0', axis=1)
features = features.drop('date', axis=1)
features = features.drop('volume', axis=1)

# %%
features = features[~features.isin([np.nan, np.inf, -np.inf]).any(1)]

# %%
features.columns
# Out:
# Index(['open', 'close', 'low', 'high', 'bb_bbm', 'bb_bbh', 'bb_bbl', 'atr',
#        'macd', 'cci', 'ema', 'roc', 'sma12', 'sma5', 'stochastic_oscillator',
#        'mtm6', 'mtm12'],
#       dtype='object')

# %%
n = features.shape[0]
n_train = 3*n//5
n_val = n//5

# %%
#features = features.drop('volume', axis=1)
#features = features.drop('Unnamed: 0', axis=1)
y = features['close']
x = features.drop('close', axis=1)

# %%
plt.plot(y)

# %%
x.shape
# Out:
# (5079, 16)

# %%
train = x.iloc[:n_train,:]
test = x.iloc[n_train:,:]

# %%
test.shape
# Out:
# (2032, 16)

# %%
a_train_y = y[:n_train]
train_y = a_train_y
a_test_y = y[n_train:]
test_y = a_test_y

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
test_y = scaler.fit_transform(np.array(test_y).reshape(-1,1))
train_y = scaler.transform(np.array(train_y).reshape(-1,1))

# %%
a_train_x = train
a_test_x = test

# %%
a_train_x
# Out:
#          open      low     high     bb_bbm     bb_bbh     bb_bbl       atr  \
# 0      4.0714   3.9755   4.1451   3.742555   4.258224   3.226886  0.258809
# 1      4.0804   4.0179   4.1786   3.778050   4.267487   3.288613  0.251801
# 2      4.0224   3.9130   4.0670   3.825040   4.222099   3.427981  0.244815
# 11                70.685456  -3.202353   0.986818
# 12                31.769894  -3.125922  -3.916933
# 13                49.165954  -1.413703   0.554395
# 14                59.666382   3.032744   0.991711
# 15                93.766060  14.497638  19.827497
# 16                60.596581   4.947252   5.343069
# 17                84.415149  11.096526   7.538824
# 18                75.310021  13.873668  10.314067
# 19                64.082225   8.497540   6.963707
# 20                60.596581   6.434120   9.661994
# 21                61.590884  -6.188092   7.412419
# 22                75.555804   3.073074   8.172359
# 23                54.743913  -5.203046   5.316123
# 24                24.493223  -9.100225   3.510908
# 25                33.057455  -5.391487   2.647910
# 26                55.823438  -0.358028   6.053056
# 27                64.276364   2.249147  -4.078125
# 28                50.172902  -2.186547   0.819334
# 29                92.264851  11.231131   5.443725
# ...                     ...        ...        ...
# 3017              68.821234   1.740484  10.071125
# 3018              82.672666   3.823097  12.900863
# 3019              82.756241   2.145942  11.890735
# 3020              87.121766   1.028446  11.238874
# 3021              94.143687   5.710738  11.383631
# 3022              96.531551   4.400833  10.400649
# 3023              99.698016   6.761335   8.619499
# 3024              93.294989   5.612216   9.649873
# 3025              95.549119   6.174186   8.452622
# 3026              94.313212   5.377735   6.461488
# 3027              73.953633   1.952050   7.774264
# 3028              71.942255   0.912216   5.353194
# 3029              72.288448  -1.142632   5.541446
# 3030              87.137657  -0.084798   5.522659
# 3031              93.098818  -0.078819   6.090500
# 3032              99.477662   1.687558   7.156045
# 3033              99.573957   6.811253   8.896261
# 3034              98.345267  11.614371  12.632535
# 3035              82.394177  10.186560   8.927534
# 3036              82.016807   7.955392   7.863849
# 3037              96.882133  10.965896  10.878434
# 3038              97.300882   9.257108  11.100885
# 3039              93.750236   6.211649  13.445993
# 3040              87.926266   0.961799  12.687877
# 3041              85.266744   1.807586  12.178277
# 3042              96.423407   3.675300  11.923077
# 3043              98.239393   1.681982  12.832322
# 3044              95.464657   2.069338  11.518007
# 3045              81.359873   0.506890   6.750026
# 3046              71.063330   0.492989   1.459529
#
# [3047 rows x 16 columns]

# %%
scaler = MinMaxScaler(feature_range=(-1, 1))
x_train_a = scaler.fit_transform(a_train_x)
x_test_a = scaler.transform(a_test_x)

# %%
x_train_a.shape
# Out:
# (3047, 16)

# %%
autoencoder = AutoEncoder(10, x_train_a.shape[1])
autoencoder.build_model()

# %%
print('Training model...')
autoencoder.train_model(autoencoder.autoencoder, x_train_a, epochs=100, model_name='autoencoder')
# Out:
# Training model...
# Epoch 1/100
# 3047/3047 [==============================] - 2s 536us/step - loss: 0.4261 - acc: 0.0466 - mae: 0.5475
# Epoch 2/100
# 3047/3047 [==============================] - 1s 175us/step - loss: 0.4006 - acc: 0.2350 - mae: 0.5286 0s - loss: 0.4005 - acc: 0.2462 - mae: 0.5
# Epoch 3/100
# 3047/3047 [==============================] - 1s 175us/step - loss: 0.3992 - acc: 0.1995 - mae: 0.5259
# Epoch 4/100
# 3047/3047 [==============================] - 1s 198us/step - loss: 0.3985 - acc: 0.1926 - mae: 0.5244
# Epoch 5/100
# 3047/3047 [==============================] - 1s 195us/step - loss: 0.3980 - acc: 0.1999 - mae: 0.5233
# Epoch 6/100
# Epoch 81/100
# 3047/3047 [==============================] - 1s 169us/step - loss: 0.3816 - acc: 0.7414 - mae: 0.4940
# Epoch 82/100
# 3047/3047 [==============================] - 0s 161us/step - loss: 0.3816 - acc: 0.7424 - mae: 0.4939
# Epoch 83/100
# 3047/3047 [==============================] - ETA: 0s - loss: 0.3824 - acc: 0.7377 - mae: 0.495 - 1s 188us/step - loss: 0.3816 - acc: 0.7411 - mae: 0.4939
# Epoch 84/100
# 3047/3047 [==============================] - 0s 153us/step - loss: 0.3816 - acc: 0.7424 - mae: 0.4939
# Epoch 85/100
# 3047/3047 [==============================] - 1s 165us/step - loss: 0.3816 - acc: 0.7434 - mae: 0.4939
# Epoch 86/100
# 3047/3047 [==============================] - 1s 169us/step - loss: 0.3816 - acc: 0.7430 - mae: 0.4939
# Epoch 87/100
# 3047/3047 [==============================] - 1s 198us/step - loss: 0.3816 - acc: 0.7430 - mae: 0.4940
# Epoch 88/100
# 3047/3047 [==============================] - 0s 160us/step - loss: 0.3816 - acc: 0.7434 - mae: 0.4940
# Epoch 89/100
# 3047/3047 [==============================] - 0s 156us/step - loss: 0.3816 - acc: 0.7430 - mae: 0.4939
# Epoch 90/100
# 3047/3047 [==============================] - 1s 182us/step - loss: 0.3816 - acc: 0.7420 - mae: 0.4939
# Epoch 91/100
# 3047/3047 [==============================] - 0s 161us/step - loss: 0.3816 - acc: 0.7427 - mae: 0.4939
# Epoch 92/100
# 3047/3047 [==============================] - 1s 198us/step - loss: 0.3816 - acc: 0.7440 - mae: 0.4939
# Epoch 93/100
# 3047/3047 [==============================] - 1s 203us/step - loss: 0.3816 - acc: 0.7427 - mae: 0.4939
# Epoch 94/100
# 3047/3047 [==============================] - 1s 166us/step - loss: 0.3816 - acc: 0.7434 - mae: 0.4938
# Epoch 95/100
# 3047/3047 [==============================] - 1s 200us/step - loss: 0.3816 - acc: 0.7434 - mae: 0.4938
# Epoch 96/100
# 3047/3047 [==============================] - 1s 167us/step - loss: 0.3816 - acc: 0.7440 - mae: 0.4939
# Epoch 97/100
# 3047/3047 [==============================] - 1s 171us/step - loss: 0.3816 - acc: 0.7437 - mae: 0.4938
# Epoch 98/100
# 3047/3047 [==============================] - 0s 149us/step - loss: 0.3816 - acc: 0.7437 - mae: 0.4939
# Epoch 99/100
# 3047/3047 [==============================] - 1s 185us/step - loss: 0.3816 - acc: 0.7457 - mae: 0.4938
# Epoch 100/100
# 3047/3047 [==============================] - 1s 197us/step - loss: 0.3816 - acc: 0.7440 - mae: 0.4938

# %%
print('Testing model...')
autoencoder.test_model(autoencoder.autoencoder, x_test_a)
# Out:
# Testing model...
# 2032/2032 [==============================] - 0s 133us/step
# [0.6403722793861167, 0.8252952694892883, 0.39791339635849]

# %%
a_scaled_full = pd.DataFrame(scaler.transform(x))

# %%
a_scaled_full.shape
# Out:
# (5079, 16)

# %%
autoencoder.encode_data(a_scaled_full, csv_path='./full_x.csv')
# Out:
#              0         1         2         3         4          5         6  \
# 0     0.136135  0.592276  1.035127  0.000000  1.045130   0.000000  0.000000
# 5056  0.000000  0.000000  2.355174
# 5057  0.000000  0.000000  2.294067
# 5058  0.000000  0.000000  2.202908
# 5059  0.000000  0.000000  2.100085
# 5060  0.000000  0.000000  2.414714
# 5061  0.000000  0.000000  2.302311
# 5062  0.000000  0.000000  2.589289
# 5063  0.000000  0.000000  2.419384
# 5064  0.000000  0.000000  2.429183
# 5065  0.000000  0.000000  2.087273
# 5066  0.000000  0.000000  2.035784
# 5067  0.000000  0.000000  2.022149
# 5068  0.000000  0.000000  1.909269
# 5069  0.000000  0.000000  2.155782
# 5070  0.000000  0.000000  2.283760
# 5071  0.000000  0.000000  2.261177
# 5072  0.000000  0.000000  2.031243
# 5073  0.000000  0.000000  2.334369
# 5074  0.000000  0.000000  2.443230
# 5075  0.000000  0.000000  2.508268
# 5076  0.000000  0.000000  2.741272
# 5077  0.000000  0.000000  1.986974
# 5078  0.000000  0.000000  2.007734
#
# [5079 rows x 10 columns]

# %%
df1 = pd.read_csv("./full_x.csv", index_col=0)
df2 = pd.DataFrame(y)

# %%
(df1.shape, df2.shape)
# Out:
# ((5079, 10), (5079, 1))

# %%
train_x = df1.iloc[:n_train,:]
test_x = df1.iloc[n_train:, :]

# %%
'''fulldata, y_values, train_x, train_y, test_x, test_y =  preprocess.make_train_test(df_x=df1, df_y=df2, window=1, 
csv_path="sample_data/processed_data/rf_data", has_y=True, binary_y=True, save_csv=True)
y = pd.read_csv('sample_data/processed_data/rf_data/full_y.csv', index_col=0)
preprocess.check_labels(y)'''
# Out:
# 'fulldata, y_values, train_x, train_y, test_x, test_y =  preprocess.make_train_test(df_x=df1, df_y=df2, window=1, \ncsv_path="sample_data/processed_data/rf_data", has_y=True, binary_y=True, save_csv=True)\ny = pd.read_csv(\'sample_data/processed_data/rf_data/full_y.csv\', index_col=0)\npreprocess.check_labels(y)'

# %%
'''train_x = pd.read_csv('sample_data/processed_data/rf_data/train_x.csv', index_col=0)
train_y = pd.read_csv('sample_data/processed_data/rf_data/train_y.csv', index_col=0)
test_x = pd.read_csv('sample_data/processed_data/rf_data/test_x.csv', index_col=0)
test_y = pd.read_csv('sample_data/processed_data/rf_data/test_y.csv', index_col=0)'''
train_x.head()
# Out:
#           0         1         2    3         4    5    6         7         8  \
# 0  0.136135  0.592276  1.035127  0.0  1.045130  0.0  0.0  0.729582  0.532910
# 1  0.139191  0.570039  0.984426  0.0  1.047860  0.0  0.0  0.776938  0.559366
# 2  0.139088  0.562624  1.012027  0.0  1.025209  0.0  0.0  0.859197  0.552159
# 3  0.101978  0.533991  1.139696  0.0  0.862831  0.0  0.0  0.649261  0.534463
# 4  0.160763  0.563942  0.993129  0.0  1.110218  0.0  0.0  0.972462  0.589738
#
#           9
# 0  1.129910
# 1  1.158163
# 2  1.227446
# 3  0.895877
# 4  1.396203

# %%
val_x = test_x.iloc[:n_val,:]
test_x = test_x.iloc[n_val:,:]

# %%
scaler = MinMaxScaler(feature_range=(-1, 1))
x_train = scaler.fit_transform(train_x)
x_test = scaler.transform(test_x)
x_val = scaler.transform(val_x)

# %%
pd.DataFrame(x_val).max(axis=0)
# Out:
# 0    11.813074
# 1     0.794615
# 2    -0.446531
# 3    14.415135
# 4     2.822003
# 5     3.686046
# 6    12.167271
# 7     3.533946
# 8    -1.000000
# 9     1.119686
# dtype: float64

# %%
pd.DataFrame(x_train).head()
# Out:
#           0         1         2    3         4    5    6         7         8  \
# 0 -0.459827  0.287004 -0.074056 -1.0  0.355995 -1.0 -1.0  0.301446  0.002121
# 1 -0.447700  0.238682 -0.119409 -1.0  0.359537 -1.0 -1.0  0.385920  0.051871
# 2 -0.448108  0.222570 -0.094719 -1.0  0.330149 -1.0 -1.0  0.532657  0.038318
# 3 -0.595360  0.160351  0.019484 -1.0  0.119472 -1.0 -1.0  0.158168  0.005042
# 4 -0.362102  0.225433 -0.111624 -1.0  0.440443 -1.0 -1.0  0.734700  0.108984
#
#           9
# 0  0.196840
# 1  0.226768
# 2  0.300154
# 3 -0.051056
# 4  0.478907

# %%
#nnmodel = NNModel(x_train.shape[1])
#nnmodel.make_model()

#print('Training model...')
#nnmodel.train_model(x_train, train_y, model_name='nnmodel', epochs=1000)

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM

# %%
len(x_train)
# Out:
# 3047

# %%
X_train= np.reshape(x_train, (len(x_train), 1, x_train.shape[1]))
X_test=np.reshape(x_test, (len(x_test), 1, x_test.shape[1]))
X_val=np.reshape(x_val, (len(x_val), 1, x_val.shape[1]))

# %%
val_y = test_y[:n_val]
test_y = test_y[n_val:]

# %%
X_test.shape
# Out:
# (1017, 1, 10)

# %%
from keras.models import load_model
from keras import regularizers
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping

# %%
#model = load_model('./models/attempt1.h5')

# %%
neurons=60
dropout=0.20
model = Sequential()
model.add(LSTM(neurons, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2]), activation='relu'))
model.add(Dropout(dropout))
model.add(LSTM(neurons*2, return_sequences=True, activation='relu'))
model.add(Dropout(dropout))
model.add(LSTM(neurons, activation='relu'))
model.add(Dense(units=1))
model.add(Activation('relu'))
model.compile(loss='mse', optimizer='adam')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 1, 60)             17040
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 60)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1, 120)            86880
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 120)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 60)                43440
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 61
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 147,421
# Trainable params: 147,421
# Non-trainable params: 0
# _________________________________________________________________

# %%
#scaler = MinMaxScaler(feature_range=(0, 1))

# %%
print(train_y.shape, test_y.shape)
print(X_train.shape, X_test.shape)
#train_y = np.array(scaler.fit_transform(np.array(train_y).reshape(-1,1)))
#test_y = np.array(scaler.fit_transform(np.array(test_y).reshape(-1,1)))
# Out:
# (3047, 1) (1017, 1)
# (3047, 1, 10) (1017, 1, 10)

# %%
np.array(train_y)
# Out:
# array([[-0.17381206],
#        [-0.17408241],
#        [-0.17397736],
#        ...,
#        [ 0.10938101],
#        [ 0.10423491],
#        [ 0.10157989]])

# %%
es=EarlyStopping(monitor='val_loss', mode='min', patience=50, verbose=1)

# %%
history = model.fit(X_train, train_y, epochs=1000, validation_data = (X_val, val_y), callbacks=[es])
model.save('./models/attempt9.h5')
plt.plot(history.history['loss'], label='train')
# Out:
# Train on 3047 samples, validate on 1015 samples
# Epoch 1/1000
# 3047/3047 [==============================] - 8s 3ms/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 2/1000
# 3047/3047 [==============================] - 1s 476us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 3/1000
# 3047/3047 [==============================] - 2s 503us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 4/1000
# 3047/3047 [==============================] - 2s 516us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 5/1000
# 3047/3047 [==============================] - 2s 495us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 6/1000
# 3047/3047 [==============================] - 2s 517us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 7/1000
# 3047/3047 [==============================] - 1s 454us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 8/1000
# 3047/3047 [==============================] - 2s 580us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 9/1000
# 3047/3047 [==============================] - 2s 511us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 10/1000
# 3047/3047 [==============================] - 1s 485us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 11/1000
# 3047/3047 [==============================] - 1s 426us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 12/1000
# 3047/3047 [==============================] - 1s 459us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 13/1000
# 3047/3047 [==============================] - 1s 474us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 14/1000
# 3047/3047 [==============================] - 1s 489us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 15/1000
# 3047/3047 [==============================] - 1s 435us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 16/1000
# 3047/3047 [==============================] - 1s 442us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 17/1000
# 3047/3047 [==============================] - 1s 409us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 18/1000
# 3047/3047 [==============================] - 1s 446us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 19/1000
# 3047/3047 [==============================] - 1s 434us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 20/1000
# 3047/3047 [==============================] - 1s 445us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 21/1000
# 3047/3047 [==============================] - 1s 429us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 22/1000
# 3047/3047 [==============================] - 1s 467us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 23/1000
# 3047/3047 [==============================] - 1s 440us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 24/1000
# 3047/3047 [==============================] - 1s 427us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 25/1000
# 3047/3047 [==============================] - 2s 517us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 26/1000
# 3047/3047 [==============================] - 2s 496us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 27/1000
# 3047/3047 [==============================] - 2s 558us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 28/1000
# 3047/3047 [==============================] - 2s 522us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 29/1000
# 3047/3047 [==============================] - 1s 475us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 30/1000
# 3047/3047 [==============================] - 2s 503us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 31/1000
# 3047/3047 [==============================] - 1s 484us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 32/1000
# 3047/3047 [==============================] - 1s 482us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 33/1000
# 3047/3047 [==============================] - 2s 499us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 34/1000
# 3047/3047 [==============================] - 2s 509us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 35/1000
# 3047/3047 [==============================] - 2s 554us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 36/1000
# 3047/3047 [==============================] - 2s 554us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 37/1000
# 3047/3047 [==============================] - 1s 437us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 38/1000
# 3047/3047 [==============================] - 1s 453us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 39/1000
# 3047/3047 [==============================] - 1s 429us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 40/1000
# 3047/3047 [==============================] - 1s 452us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 41/1000
# 3047/3047 [==============================] - 1s 442us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 42/1000
# 3047/3047 [==============================] - 2s 519us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 43/1000
# 3047/3047 [==============================] - 1s 471us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 44/1000
# 3047/3047 [==============================] - 2s 561us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 45/1000
# 3047/3047 [==============================] - 2s 623us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 46/1000
# 3047/3047 [==============================] - 1s 476us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 47/1000
# 3047/3047 [==============================] - 2s 497us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 48/1000
# 3047/3047 [==============================] - 2s 546us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 49/1000
# 3047/3047 [==============================] - 1s 486us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 50/1000
# 3047/3047 [==============================] - 2s 525us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 51/1000
# 3047/3047 [==============================] - 1s 423us/step - loss: 0.0215 - val_loss: 0.0202
# Epoch 00051: early stopping

# %%
'''opt = Adam(learning_rate=0.1)
original_model = Sequential()
original_model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True, activity_regularizer=regularizers.l2(0.03),
                       recurrent_regularizer=regularizers.l2(0.003), dropout=0.2))
original_model.add(Dense(50, activation="sigmoid", activity_regularizer=regularizers.l2(0.005)))
original_model.add(LSTM(20, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False, activity_regularizer=regularizers.l2(0.01),
                       recurrent_regularizer=regularizers.l2(0.001), dropout=0.2))
original_model.add(Dense(1, activation="relu", activity_regularizer=regularizers.l2(0.001)))
original_model.compile(loss='mse', optimizer=opt)
original_model.summary()'''
# Out:
# 'opt = Adam(learning_rate=0.1)\noriginal_model = Sequential()\noriginal_model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True, activity_regularizer=regularizers.l2(0.03),\n                       recurrent_regularizer=regularizers.l2(0.003), dropout=0.2))\noriginal_model.add(Dense(50, activation="sigmoid", activity_regularizer=regularizers.l2(0.005)))\noriginal_model.add(LSTM(20, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False, activity_regularizer=regularizers.l2(0.01),\n                       recurrent_regularizer=regularizers.l2(0.001), dropout=0.2))\noriginal_model.add(Dense(1, activation="relu", activity_regularizer=regularizers.l2(0.001)))\noriginal_model.compile(loss=\'mse\', optimizer=opt)\noriginal_model.summary()'

# %%
stop = time.time()

# %%
'''o_history = original_model.fit(X_train, train_y, epochs=1000)
original_model.save('./models/attempt2.h5')
plt.plot(o_history.history['loss'], label='train')'''
# Out:
# "o_history = original_model.fit(X_train, train_y, epochs=1000)\noriginal_model.save('./models/attempt2.h5')\nplt.plot(o_history.history['loss'], label='train')"

# %%
#plt.plot(o_history.history['loss'], label='train')

# %%
'''model.compile(optimizer = "adam", loss="mean_squared_error")
history = model.fit(X_train, train_y, epochs=5000)
model.save('./models/attempt1.h5')
plt.plot(history.history['loss'], label='train')'''
# Out:
# 'model.compile(optimizer = "adam", loss="mean_squared_error")\nhistory = model.fit(X_train, train_y, epochs=5000)\nmodel.save(\'./models/attempt1.h5\')\nplt.plot(history.history[\'loss\'], label=\'train\')'

# %%
#nnmodel.test_model(x_test, test_y[1:])
pred_ret = model.predict(X_test)
#pred_ret = nnmodel.predict_ret(x_test, y=None)

# %%
'''pred = model.predict(X_train)
plt.plot(pred, color='r')
plt.plot(train_y, color='g')'''
# Out:
# "pred = model.predict(X_train)\nplt.plot(pred, color='r')\nplt.plot(train_y, color='g')"

# %%
plt.plot(pred_ret, color='r')
plt.plot(np.array(test_y), color='g')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
pred = scaler.fit_transform(np.array(pred_ret).reshape(-1,1))
actual = scaler.fit_transform(np.array(test_y).reshape(-1,1))

# %%
from sklearn.utils import check_array

# %%
pred_ret.shape
# Out:
# (1017, 1)

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_pred = np.array(y_pred)
    y_true = np.array(y_true)
    #y_true, y_pred = check_array(y_true, y_pred)
    ## Note: does not handle mix 1d representation
    #if _is_1d(y_true): 
    #    y_true, y_pred = _check_1d_array(y_true, y_pred)
    diff = np.divide(np.abs(np.subtract(y_true, y_pred)), y_pred)
    print(diff)
    print(diff.shape)
    return np.mean(diff) * 100

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
import math
mse = mean_squared_error(actual, pred)
rmse = math.sqrt(mse)
mae = mean_absolute_error(actual, pred)
mape = mean_absolute_percentage_error(np.array(test_y), pred_ret)
print("mse, rmse, mae:" + str((mse,rmse,mae)))
# Out:
# [[inf]
#  [inf]
#  [inf]
#  ...
#  [inf]
#  [inf]
#  [inf]]
# (1017, 1)
# mse, rmse, mae:(0.17260273275480334, 0.4154548504408191, 0.35010975372011915)
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in true_divide

# %%
pd.Series(np.array(test_y)) - pd.Series(np.array(pred_ret))
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-65-5e97eaba42a2> in <module>
# ----> 1 pd.Series(np.array(test_y)) - pd.Series(np.array(pred_ret))
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     260             else:
#     261                 data = sanitize_array(data, index, dtype, copy,
# --> 262                                       raise_cast_failure=True)
#     263
#     264                 data = SingleBlockManager(data, index, fastpath=True)
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     656     elif subarr.ndim > 1:
#     657         if isinstance(data, np.ndarray):
# --> 658             raise Exception('Data must be 1-dimensional')
#     659         else:
#     660             subarr = com.asarray_tuplesafe(data, dtype=dtype)
#
# Exception: Data must be 1-dimensional

# %%
stop - start
# Out:
# 170.85129690170288
